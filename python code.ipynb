# %%
import pandas as pd 
import io
import seaborn as sns
import numpy as np
import matplotlib .pyplot as plt
database=pd.read_csv('weatherAUS.csv')
database.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
database['MinTemp'].min()
# Out:
# -8.5

# %%
database.shape
# Out:
# (145460, 23)

# %%
database['Date'][database['RainToday']=='Yes']
# Out:
# 9         2008-12-10
# 11        2008-12-12
# 12        2008-12-13
# 13        2008-12-14
# 17        2008-12-18
#              ...
# 145325    2017-02-11
# 145391    2017-04-18
# 145392    2017-04-19
# 145393    2017-04-20
# 145394    2017-04-21
# Name: Date, Length: 31880, dtype: object

# %%
database[database.MaxTemp==database.MaxTemp.max()]
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 106316  2011-01-25  Woomera     25.1     48.1       0.0         22.4
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 106316      12.8         WSW           85.0        NNE  ...        21.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 106316          7.0       1003.4       1000.4       3.0       2.0     33.2
#
#         Temp3pm  RainToday  RainTomorrow
# 106316     46.1         No            No
#
# [1 rows x 23 columns]

# %%
database.Location
# Out:
# 0         Albury
# 1         Albury
# 2         Albury
# 3         Albury
# 4         Albury
#            ...
# 145455     Uluru
# 145456     Uluru
# 145457     Uluru
# 145458     Uluru
# 145459     Uluru
# Name: Location, Length: 145460, dtype: object

# %%
database['MinTemp'].min()
# Out:
# -8.5

# %%
database.isnull()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       False     False    False    False     False         True      True
# 1       False     False    False    False     False         True      True
# 2       False     False    False    False     False         True      True
# 3       False     False    False    False     False         True      True
# 4       False     False    False    False     False         True      True
# ...       ...       ...      ...      ...       ...          ...       ...
# 145455  False     False    False    False     False         True      True
# 145456  False     False    False    False     False         True      True
# 145457  False     False    False    False     False         True      True
# 145458  False     False    False    False     False         True      True
# 145459  False     False    False     True     False         True      True
#
# ...

# %%
database.isnull().sum()
# Out:
# Date                 0
# Location             0
# MinTemp           1485
# MaxTemp           1261
# Rainfall          3261
# Evaporation      62790
# Sunshine         69835
# WindGustDir      10326
# WindGustSpeed    10263
# WindDir9am       10566
# WindDir3pm        4228
# WindSpeed9am      1767
# WindSpeed3pm      3062
# Humidity9am       2654
# Humidity3pm       4507
# Pressure9am      15065
# Pressure3pm      15028
# Cloud9am         55888
# Cloud3pm         59358
# Temp9am           1767
# Temp3pm           3609
# RainToday         3261
# RainTomorrow      3267
# dtype: int64

# %%
database.isnull()
# Out:
#          Date  Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0       False     False    False    False     False         True      True
# 1       False     False    False    False     False         True      True
# 2       False     False    False    False     False         True      True
# 3       False     False    False    False     False         True      True
# 4       False     False    False    False     False         True      True
# ...       ...       ...      ...      ...       ...          ...       ...
# 145455  False     False    False    False     False         True      True
# 145456  False     False    False    False     False         True      True
# 145457  False     False    False    False     False         True      True
# 145458  False     False    False    False     False         True      True
# 145459  False     False    False     True     False         True      True
#
# ...

# %%
database.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall   Evaporation  \
# count  143975.000000  144199.000000  142199.000000  82670.000000
# mean       12.194034      23.221348       2.360918      5.468232
# std         6.398495       7.119049       8.478060      4.193704
# min        -8.500000      -4.800000       0.000000      0.000000
# 25%         7.600000      17.900000       0.000000      2.600000
# 50%        12.000000      22.600000       0.000000      4.800000
# 75%        16.900000      28.200000       0.800000      7.400000
# max        33.900000      48.100000     371.000000    145.000000
#
#            Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  75625.000000  135197.000000  143693.000000  142398.000000
# mean       7.611178      40.035230      14.043426      18.662657
# std        3.785483      13.607062       8.915375       8.809800
# min        0.000000       6.000000       0.000000       0.000000
# ...

# %%
database[['Sunshine', 'Evaporation']] = database[['Sunshine', 'Evaporation']].fillna(80)
database
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6         80.0
# 1       2008-12-02   Albury      7.4     25.1       0.0         80.0
# 2       2008-12-03   Albury     12.9     25.7       0.0         80.0
# 3       2008-12-04   Albury      9.2     28.0       0.0         80.0
# 4       2008-12-05   Albury     17.5     32.3       1.0         80.0
# ...            ...      ...      ...      ...       ...          ...
# 145455  2017-06-21    Uluru      2.8     23.4       0.0         80.0
# 145456  2017-06-22    Uluru      3.6     25.3       0.0         80.0
# 145457  2017-06-23    Uluru      5.4     26.9       0.0         80.0
# 145458  2017-06-24    Uluru      7.8     27.0       0.0         80.0
# 145459  2017-06-25    Uluru     14.9      NaN       0.0         80.0
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# ...

# %%
ax=sns.countplot(database['RainTomorrow'],label='count')
Yes,No=database['RainTomorrow'].value_counts()
print('no rain',No)
print('rain',Yes)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# no rain 31877
# rain 110316

# %%
x=database.iloc[:,[2,3,4,5,6,13,14,15,16,17,18,19,20]].values
y=database.iloc[:,22].values

x
# Out:
# array([[13.4, 22.9,  0.6, ...,  nan, 16.9, 21.8],
#        [ 7.4, 25.1,  0. , ...,  nan, 17.2, 24.3],
#        [12.9, 25.7,  0. , ...,  2. , 21. , 23.2],
#        ...,
#        [ 5.4, 26.9,  0. , ...,  nan, 12.5, 26.1],
#        [ 7.8, 27. ,  0. , ...,  2. , 15.1, 26. ],
#        [14.9,  nan,  0. , ...,  8. , 15. , 20.9]])

# %%
database.RainTomorrow.value_counts()
# Out:
# No     110316
# Yes     31877
# Name: RainTomorrow, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder
lb=LabelEncoder()
y=lb.fit_transform(y)
y
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
y
# Out:
# array([0, 0, 0, ..., 0, 0, 2])

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.15)

# %%
x_test.shape
# Out:
# (21819, 13)

# %%
x_train.shape
# Out:
# (123641, 13)

# %%
y_train.shape
# Out:
# (123641,)

# %%
database.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  143975.000000  144199.000000  142199.000000  145460.000000
# mean       12.194034      23.221348       2.360918      37.640992
# std         6.398495       7.119049       8.478060      37.051463
# min        -8.500000      -4.800000       0.000000       0.000000
# 25%         7.600000      17.900000       0.000000       4.000000
# 50%        12.000000      22.600000       0.000000       9.600000
# 75%        16.900000      28.200000       0.800000      80.000000
# max        33.900000      48.100000     371.000000     145.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  145460.000000  135197.000000  143693.000000  142398.000000
# mean       42.364879      40.035230      14.043426      18.662657
# std        36.268703      13.607062       8.915375       8.809800
# min         0.000000       6.000000       0.000000       0.000000
# ...

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x_train=sc.fit_transform(x_train)
x_test=sc.fit_transform(x_test)

# %%
pip install tf
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
import keras
from keras.models import Sequential
from keras.layers import Dense

# %%
classifier = Sequential()

classifier.add(Dense(input_dim=13,units=30,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=30,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=15,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=8,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=4,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=2,kernel_initializer='uniform',activation='sigmoid'))

classifier.add(Dense(units=1,activation='sigmoid'))

classifier.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])

classifier.fit(x_train,y_train,batch_size=300,epochs=10)
# Out:
# Epoch 1/10
# 413/413 [==============================] - 2s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 2/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 3/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 4/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 5/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 6/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 7/10
# 413/413 [==============================] - 1s 3ms/step - loss: nan - accuracy: 0.7580
# Epoch 8/10
# 413/413 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.7580
# Epoch 9/10
# 413/413 [==============================] - 1s 2ms/step - loss: nan - accuracy: 0.7580
# Epoch 10/10
# ...

# %% [markdown]
# ######

# %%
y_pred=classifier.predict(x_test)
y_pred=(y_pred>0.5)
print(y_pred)
# Out:
# 682/682 [==============================] - 1s 1ms/step
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
from sklearn.metrics import confusion_matrix
cm=confusion_matrix(y_test,y_pred)
sns.heatmap(cm,annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #
